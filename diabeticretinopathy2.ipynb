# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import os
from tqdm import tqdm
from keras.applications.densenet import DenseNet121, preprocess_input
# Out:
# Using TensorFlow backend.

# %%
csv = pd.read_csv('/DR_id.csv')
csv_id = list(csv['id_code'].values)
csv_diag = list(csv['diagnosis'].values)
csv.head()
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
def crop_image_from_gray(img,tol=7):
    if img.ndim ==2:
        mask = img>tol
        return img[np.ix_(mask.any(1),mask.any(0))]
    elif img.ndim==3:
        gray_img = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        mask = gray_img>tol
        
        check_shape = img[:,:,0][np.ix_(mask.any(1),mask.any(0))].shape[0]
        if (check_shape == 0): # image is too dark so that we crop out everything,
            return img # return original image
        else:
            img1=img[:,:,0][np.ix_(mask.any(1),mask.any(0))]
            img2=img[:,:,1][np.ix_(mask.any(1),mask.any(0))]
            img3=img[:,:,2][np.ix_(mask.any(1),mask.any(0))]
    #         print(img1.shape,img2.shape,img3.shape)
            img = np.stack([img1,img2,img3],axis=-1)
    #         print(img.shape)
        return img

# %%
def data_generator(path):
    images = []
    labels = []
    for i in tqdm(os.listdir(path)):
        img_path = path + '/' + i
        img = cv2.imread(img_path)
        img = crop_image_from_gray(img,tol=7)
#        img = cv2.addWeighted(img,4, cv2.GaussianBlur(img,(0,0),20),-4,128)
        img = cv2.resize(img,(224,224))
        index = csv_id.index(i[:-4])
        labels.append(csv_diag[index])
        images.append(img)
    images = np.array(images)/255
    labels = np.array(labels)
    return images, labels

# %%
x_train, y_train = data_generator(path='/train')
x_valid, y_valid = data_generator(path='/valid')
# Out:
# 100%|██████████| 2662/2662 [06:53<00:00,  6.44it/s]
# 100%|██████████| 500/500 [01:15<00:00,  6.64it/s]

# %%
plt.figure(figsize=(20,20))
for i in range(1,26):
    n = np.random.randint(50)
    plt.subplot(5,5,i)
    plt.imshow(x_train[n])
    plt.title(y_train[n])

# %%
from keras.utils import np_utils
y_train = np_utils.to_categorical(y_train, 5)
y_valid = np_utils.to_categorical(y_valid, 5)

# %%
y_train_multi = np.empty(y_train.shape, dtype=y_train.dtype)
y_train_multi[:, 4] = y_train[:, 4]

for i in range(3, -1, -1):
    y_train_multi[:, i] = np.logical_or(y_train[:, i], y_train_multi[:, i+1])

y_valid_multi = np.empty(y_valid.shape, dtype=y_train.dtype)
y_valid_multi[:, 4] = y_valid[:, 4]

for i in range(3, -1, -1):
    y_valid_multi[:, i] = np.logical_or(y_valid[:, i], y_valid_multi[:, i+1])

# %%
from keras.preprocessing.image import ImageDataGenerator
datagen = ImageDataGenerator(zoom_range=0.2, horizontal_flip=True, vertical_flip=True,
                            fill_mode='constant', cval=0.)
train_gen = datagen.flow(x_train, y_train_multi, batch_size=32)

# %%
a=0;b=0;c=0;d=0;e=0
train_labels = []
for j in os.listdir('/train'):
  no = csv_id.index(j[:-4])
  i = csv_diag[no]
  train_labels.append(i)
  if i == 0:
    a += 1
  if i == 1:
    b += 1
  if i == 2:
    c += 1
  if i == 3:
    d += 1
  if i == 4:
    e += 1
class_cnt = {'No DR':a , 'Mild':b, 'Moderate':c, 'Severe':d, 'Proliferative DR':e}
plt.bar(class_cnt.keys(), class_cnt.values())
# Out:
# <BarContainer object of 5 artists>

# %%
from keras import backend as K

def sensitivity_m(y_true, y_pred):
        true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
        possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
        sensitivity = true_positives / (possible_positives + K.epsilon())
        return sensitivity

def specificity_m(y_true, y_pred):
        true_negatives  = K.sum(K.round(K.clip((1-y_true) * (1-y_pred), 0, 1)))
        possible_negatives  = K.sum(K.round(K.clip(1-y_true, 0, 1)))
        specificity = true_negatives / (possible_negatives + K.epsilon())
        return specificity

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Dropout, BatchNormalization, Flatten, MaxPool2D, GlobalAveragePooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras.callbacks import Callback

# %%
tr = DenseNet121(weights='imagenet', include_top=False, input_shape=(224,224,3))
# Out:
# Downloading data from https://github.com/keras-team/keras-applications/releases/download/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step

# %%
model = Sequential()
model.add(tr)
model.add(GlobalAveragePooling2D())
model.add(Dropout(0.5))
model.add(Dense(5, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy', sensitivity_m, specificity_m])
ck = ModelCheckpoint('dr_weights.hdf5', monitor='val_loss', save_best_only=True, mode='auto', verbose=1)
re = ReduceLROnPlateau(monitor='val_loss', mode='auto', factor=0.2, patience=5, verbose=1)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# densenet121 (Model)          (None, 7, 7, 1024)        7037504
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 7,042,629
# Trainable params: 6,958,981
# Non-trainable params: 83,648
# _________________________________________________________________

# %%
history = model.fit_generator(train_gen, epochs=50, steps_per_epoch=2662//32,
                     verbose=1, validation_data=(x_valid,y_valid_multi),
                    callbacks=[ck,re])
# Out:
# Epoch 1/50
# 83/83 [==============================] - 122s 1s/step - loss: 0.2307 - accuracy: 0.9065 - sensitivity_m: 0.8731 - specificity_m: 0.9357 - val_loss: 0.3426 - val_accuracy: 0.9056 - val_sensitivity_m: 0.8370 - val_specificity_m: 0.9576
#
# Epoch 00001: val_loss improved from inf to 0.34259, saving model to dr_weights.hdf5
# Epoch 2/50
# 83/83 [==============================] - 45s 544ms/step - loss: 0.1624 - accuracy: 0.9356 - sensitivity_m: 0.9088 - specificity_m: 0.9590 - val_loss: 0.4794 - val_accuracy: 0.9216 - val_sensitivity_m: 0.8462 - val_specificity_m: 0.9799
#
# Epoch 00002: val_loss did not improve from 0.34259
# Epoch 3/50
# 83/83 [==============================] - 45s 546ms/step - loss: 0.1652 - accuracy: 0.9354 - sensitivity_m: 0.9067 - specificity_m: 0.9592 - val_loss: 0.4337 - val_accuracy: 0.9188 - val_sensitivity_m: 0.8639 - val_specificity_m: 0.9618
#
# Epoch 00003: val_loss did not improve from 0.34259
# Epoch 4/50
# 83/83 [==============================] - 44s 535ms/step - loss: 0.1491 - accuracy: 0.9409 - sensitivity_m: 0.9150 - specificity_m: 0.9634 - val_loss: 0.3567 - val_accuracy: 0.8932 - val_sensitivity_m: 0.8747 - val_specificity_m: 0.9086
#
# Epoch 00004: val_loss did not improve from 0.34259
# Epoch 5/50
# 83/83 [==============================] - 46s 551ms/step - loss: 0.1573 - accuracy: 0.9411 - sensitivity_m: 0.9140 - specificity_m: 0.9625 - val_loss: 0.3176 - val_accuracy: 0.9052 - val_sensitivity_m: 0.7897 - val_specificity_m: 0.9951
#
# Epoch 00005: val_loss improved from 0.34259 to 0.31759, saving model to dr_weights.hdf5
# Epoch 6/50
# 83/83 [==============================] - 45s 548ms/step - loss: 0.1404 - accuracy: 0.9426 - sensitivity_m: 0.9202 - specificity_m: 0.9627 - val_loss: 0.1833 - val_accuracy: 0.9268 - val_sensitivity_m: 0.8520 - val_specificity_m: 0.9845
#
# Epoch 00006: val_loss improved from 0.31759 to 0.18328, saving model to dr_weights.hdf5
# Epoch 7/50
# 83/83 [==============================] - 45s 548ms/step - loss: 0.1440 - accuracy: 0.9425 - sensitivity_m: 0.9188 - specificity_m: 0.9622 - val_loss: 0.2004 - val_accuracy: 0.9356 - val_sensitivity_m: 0.8796 - val_specificity_m: 0.9790
#
# Epoch 00007: val_loss did not improve from 0.18328
# Epoch 8/50
# 83/83 [==============================] - 45s 541ms/step - loss: 0.1283 - accuracy: 0.9496 - sensitivity_m: 0.9258 - specificity_m: 0.9700 - val_loss: 0.1917 - val_accuracy: 0.9364 - val_sensitivity_m: 0.8758 - val_specificity_m: 0.9830
#
# Epoch 00008: val_loss did not improve from 0.18328
# Epoch 9/50
# 83/83 [==============================] - 45s 539ms/step - loss: 0.1229 - accuracy: 0.9493 - sensitivity_m: 0.9283 - specificity_m: 0.9681 - val_loss: 0.1991 - val_accuracy: 0.9260 - val_sensitivity_m: 0.8445 - val_specificity_m: 0.9907
#
# Epoch 00009: val_loss did not improve from 0.18328
# Epoch 10/50
# 83/83 [==============================] - 45s 545ms/step - loss: 0.1211 - accuracy: 0.9512 - sensitivity_m: 0.9345 - specificity_m: 0.9655 - val_loss: 0.1445 - val_accuracy: 0.9412 - val_sensitivity_m: 0.8764 - val_specificity_m: 0.9915
#
# Epoch 00010: val_loss improved from 0.18328 to 0.14446, saving model to dr_weights.hdf5
# Epoch 11/50
# 83/83 [==============================] - 45s 543ms/step - loss: 0.1256 - accuracy: 0.9494 - sensitivity_m: 0.9327 - specificity_m: 0.9642 - val_loss: 0.1608 - val_accuracy: 0.9432 - val_sensitivity_m: 0.8923 - val_specificity_m: 0.9819
#
# Epoch 00011: val_loss did not improve from 0.14446
# Epoch 12/50
# 83/83 [==============================] - 45s 539ms/step - loss: 0.1226 - accuracy: 0.9510 - sensitivity_m: 0.9303 - specificity_m: 0.9668 - val_loss: 0.1563 - val_accuracy: 0.9440 - val_sensitivity_m: 0.8958 - val_specificity_m: 0.9810
#
# Epoch 00012: val_loss did not improve from 0.14446
# Epoch 13/50
# 83/83 [==============================] - 45s 537ms/step - loss: 0.1112 - accuracy: 0.9544 - sensitivity_m: 0.9374 - specificity_m: 0.9692 - val_loss: 0.1817 - val_accuracy: 0.9260 - val_sensitivity_m: 0.8347 - val_specificity_m: 0.9958
#
# Epoch 00013: val_loss did not improve from 0.14446
# Epoch 14/50
# 83/83 [==============================] - 45s 546ms/step - loss: 0.1179 - accuracy: 0.9531 - sensitivity_m: 0.9359 - specificity_m: 0.9681 - val_loss: 0.2706 - val_accuracy: 0.9132 - val_sensitivity_m: 0.8072 - val_specificity_m: 0.9958
#
# Epoch 00014: val_loss did not improve from 0.14446
# Epoch 15/50
# 83/83 [==============================] - 45s 543ms/step - loss: 0.1178 - accuracy: 0.9514 - sensitivity_m: 0.9342 - specificity_m: 0.9659 - val_loss: 0.1661 - val_accuracy: 0.9480 - val_sensitivity_m: 0.9127 - val_specificity_m: 0.9769
#
# Epoch 00015: val_loss did not improve from 0.14446
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 16/50
# 83/83 [==============================] - 45s 539ms/step - loss: 0.1029 - accuracy: 0.9581 - sensitivity_m: 0.9445 - specificity_m: 0.9706 - val_loss: 0.0988 - val_accuracy: 0.9644 - val_sensitivity_m: 0.9409 - val_specificity_m: 0.9831
#
# Epoch 00016: val_loss improved from 0.14446 to 0.09880, saving model to dr_weights.hdf5
# Epoch 17/50
# 83/83 [==============================] - 44s 536ms/step - loss: 0.0960 - accuracy: 0.9620 - sensitivity_m: 0.9483 - specificity_m: 0.9746 - val_loss: 0.0933 - val_accuracy: 0.9632 - val_sensitivity_m: 0.9464 - val_specificity_m: 0.9769
#
# Epoch 00017: val_loss improved from 0.09880 to 0.09332, saving model to dr_weights.hdf5
# Epoch 18/50
# 83/83 [==============================] - 45s 544ms/step - loss: 0.0839 - accuracy: 0.9662 - sensitivity_m: 0.9553 - specificity_m: 0.9748 - val_loss: 0.0936 - val_accuracy: 0.9632 - val_sensitivity_m: 0.9442 - val_specificity_m: 0.9780
#
# Epoch 00018: val_loss did not improve from 0.09332
# Epoch 19/50
# 83/83 [==============================] - 45s 546ms/step - loss: 0.0877 - accuracy: 0.9641 - sensitivity_m: 0.9519 - specificity_m: 0.9750 - val_loss: 0.0993 - val_accuracy: 0.9628 - val_sensitivity_m: 0.9391 - val_specificity_m: 0.9810
#
# Epoch 00019: val_loss did not improve from 0.09332
# Epoch 20/50
# 83/83 [==============================] - 45s 540ms/step - loss: 0.0868 - accuracy: 0.9663 - sensitivity_m: 0.9553 - specificity_m: 0.9762 - val_loss: 0.1059 - val_accuracy: 0.9612 - val_sensitivity_m: 0.9300 - val_specificity_m: 0.9850
#
# Epoch 00020: val_loss did not improve from 0.09332
# Epoch 21/50
# 83/83 [==============================] - 45s 538ms/step - loss: 0.0792 - accuracy: 0.9687 - sensitivity_m: 0.9589 - specificity_m: 0.9766 - val_loss: 0.0933 - val_accuracy: 0.9644 - val_sensitivity_m: 0.9474 - val_specificity_m: 0.9776
#
# Epoch 00021: val_loss did not improve from 0.09332
# Epoch 22/50
# 83/83 [==============================] - 45s 539ms/step - loss: 0.1044 - accuracy: 0.9651 - sensitivity_m: 0.9482 - specificity_m: 0.9768 - val_loss: 0.1710 - val_accuracy: 0.9464 - val_sensitivity_m: 0.9043 - val_specificity_m: 0.9787
#
# Epoch 00022: val_loss did not improve from 0.09332
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23/50
# 83/83 [==============================] - 45s 543ms/step - loss: 0.0900 - accuracy: 0.9640 - sensitivity_m: 0.9559 - specificity_m: 0.9716 - val_loss: 0.1064 - val_accuracy: 0.9600 - val_sensitivity_m: 0.9340 - val_specificity_m: 0.9795
#
# Epoch 00023: val_loss did not improve from 0.09332
# Epoch 24/50
# 83/83 [==============================] - 45s 539ms/step - loss: 0.0800 - accuracy: 0.9690 - sensitivity_m: 0.9567 - specificity_m: 0.9791 - val_loss: 0.0963 - val_accuracy: 0.9640 - val_sensitivity_m: 0.9459 - val_specificity_m: 0.9777
#
# Epoch 00024: val_loss did not improve from 0.09332
# Epoch 25/50
# 83/83 [==============================] - 44s 533ms/step - loss: 0.0790 - accuracy: 0.9662 - sensitivity_m: 0.9572 - specificity_m: 0.9741 - val_loss: 0.0967 - val_accuracy: 0.9656 - val_sensitivity_m: 0.9450 - val_specificity_m: 0.9814
#
# Epoch 00025: val_loss did not improve from 0.09332
# Epoch 26/50
# 83/83 [==============================] - 45s 543ms/step - loss: 0.0872 - accuracy: 0.9689 - sensitivity_m: 0.9549 - specificity_m: 0.9791 - val_loss: 0.1034 - val_accuracy: 0.9632 - val_sensitivity_m: 0.9387 - val_specificity_m: 0.9814
#
# Epoch 00026: val_loss did not improve from 0.09332
# Epoch 27/50
# 83/83 [==============================] - 45s 539ms/step - loss: 0.0800 - accuracy: 0.9703 - sensitivity_m: 0.9589 - specificity_m: 0.9781 - val_loss: 0.0949 - val_accuracy: 0.9648 - val_sensitivity_m: 0.9491 - val_specificity_m: 0.9766
#
# Epoch 00027: val_loss did not improve from 0.09332
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# Epoch 28/50
# 83/83 [==============================] - 45s 546ms/step - loss: 0.0741 - accuracy: 0.9712 - sensitivity_m: 0.9624 - specificity_m: 0.9786 - val_loss: 0.0951 - val_accuracy: 0.9652 - val_sensitivity_m: 0.9492 - val_specificity_m: 0.9774
#
# Epoch 00028: val_loss did not improve from 0.09332
# Epoch 29/50
# 83/83 [==============================] - 44s 533ms/step - loss: 0.0742 - accuracy: 0.9722 - sensitivity_m: 0.9632 - specificity_m: 0.9796 - val_loss: 0.0958 - val_accuracy: 0.9644 - val_sensitivity_m: 0.9464 - val_specificity_m: 0.9780
#
# Epoch 00029: val_loss did not improve from 0.09332
# Epoch 30/50
# 83/83 [==============================] - 45s 540ms/step - loss: 0.0731 - accuracy: 0.9729 - sensitivity_m: 0.9643 - specificity_m: 0.9809 - val_loss: 0.0962 - val_accuracy: 0.9652 - val_sensitivity_m: 0.9455 - val_specificity_m: 0.9800
#
# Epoch 00030: val_loss did not improve from 0.09332
# Epoch 31/50
# 83/83 [==============================] - 45s 545ms/step - loss: 0.0708 - accuracy: 0.9731 - sensitivity_m: 0.9631 - specificity_m: 0.9818 - val_loss: 0.0959 - val_accuracy: 0.9656 - val_sensitivity_m: 0.9472 - val_specificity_m: 0.9794
#
# Epoch 00031: val_loss did not improve from 0.09332
# Epoch 32/50
# 83/83 [==============================] - 44s 534ms/step - loss: 0.0708 - accuracy: 0.9702 - sensitivity_m: 0.9620 - specificity_m: 0.9776 - val_loss: 0.0957 - val_accuracy: 0.9668 - val_sensitivity_m: 0.9500 - val_specificity_m: 0.9793
#
# Epoch 00032: val_loss did not improve from 0.09332
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# Epoch 33/50
# 83/83 [==============================] - 45s 537ms/step - loss: 0.0740 - accuracy: 0.9723 - sensitivity_m: 0.9604 - specificity_m: 0.9810 - val_loss: 0.0956 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9510 - val_specificity_m: 0.9793
#
# Epoch 00033: val_loss did not improve from 0.09332
# Epoch 34/50
# 83/83 [==============================] - 45s 544ms/step - loss: 0.0735 - accuracy: 0.9713 - sensitivity_m: 0.9635 - specificity_m: 0.9787 - val_loss: 0.0958 - val_accuracy: 0.9664 - val_sensitivity_m: 0.9491 - val_specificity_m: 0.9793
#
# Epoch 00034: val_loss did not improve from 0.09332
# Epoch 35/50
# 83/83 [==============================] - 45s 544ms/step - loss: 0.0702 - accuracy: 0.9737 - sensitivity_m: 0.9603 - specificity_m: 0.9823 - val_loss: 0.0959 - val_accuracy: 0.9668 - val_sensitivity_m: 0.9501 - val_specificity_m: 0.9793
#
# Epoch 00035: val_loss did not improve from 0.09332
# Epoch 36/50
# 83/83 [==============================] - 45s 545ms/step - loss: 0.0718 - accuracy: 0.9713 - sensitivity_m: 0.9592 - specificity_m: 0.9811 - val_loss: 0.0957 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9509 - val_specificity_m: 0.9793
#
# Epoch 00036: val_loss did not improve from 0.09332
# Epoch 37/50
# 83/83 [==============================] - 45s 545ms/step - loss: 0.0737 - accuracy: 0.9716 - sensitivity_m: 0.9617 - specificity_m: 0.9797 - val_loss: 0.0960 - val_accuracy: 0.9668 - val_sensitivity_m: 0.9501 - val_specificity_m: 0.9793
#
# Epoch 00037: val_loss did not improve from 0.09332
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-07.
# Epoch 38/50
# 83/83 [==============================] - 46s 548ms/step - loss: 0.0693 - accuracy: 0.9723 - sensitivity_m: 0.9639 - specificity_m: 0.9803 - val_loss: 0.0960 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9510 - val_specificity_m: 0.9793
#
# Epoch 00038: val_loss did not improve from 0.09332
# Epoch 39/50
# 83/83 [==============================] - 45s 547ms/step - loss: 0.0685 - accuracy: 0.9731 - sensitivity_m: 0.9674 - specificity_m: 0.9789 - val_loss: 0.0957 - val_accuracy: 0.9676 - val_sensitivity_m: 0.9519 - val_specificity_m: 0.9793
#
# Epoch 00039: val_loss did not improve from 0.09332
# Epoch 40/50
# 83/83 [==============================] - 45s 537ms/step - loss: 0.0689 - accuracy: 0.9714 - sensitivity_m: 0.9628 - specificity_m: 0.9785 - val_loss: 0.0958 - val_accuracy: 0.9676 - val_sensitivity_m: 0.9519 - val_specificity_m: 0.9793
#
# Epoch 00040: val_loss did not improve from 0.09332
# Epoch 41/50
# 83/83 [==============================] - 44s 535ms/step - loss: 0.0743 - accuracy: 0.9705 - sensitivity_m: 0.9598 - specificity_m: 0.9787 - val_loss: 0.0958 - val_accuracy: 0.9676 - val_sensitivity_m: 0.9519 - val_specificity_m: 0.9793
#
# Epoch 00041: val_loss did not improve from 0.09332
# Epoch 42/50
# 83/83 [==============================] - 45s 547ms/step - loss: 0.0720 - accuracy: 0.9725 - sensitivity_m: 0.9633 - specificity_m: 0.9793 - val_loss: 0.0961 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9510 - val_specificity_m: 0.9793
#
# Epoch 00042: val_loss did not improve from 0.09332
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 6.400000529538374e-08.
# Epoch 43/50
# 83/83 [==============================] - 46s 551ms/step - loss: 0.0728 - accuracy: 0.9700 - sensitivity_m: 0.9615 - specificity_m: 0.9772 - val_loss: 0.0958 - val_accuracy: 0.9676 - val_sensitivity_m: 0.9519 - val_specificity_m: 0.9793
#
# Epoch 00043: val_loss did not improve from 0.09332
# Epoch 44/50
# 83/83 [==============================] - 46s 551ms/step - loss: 0.0682 - accuracy: 0.9739 - sensitivity_m: 0.9638 - specificity_m: 0.9823 - val_loss: 0.0960 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9510 - val_specificity_m: 0.9793
#
# Epoch 00044: val_loss did not improve from 0.09332
# Epoch 45/50
# 83/83 [==============================] - 45s 545ms/step - loss: 0.0683 - accuracy: 0.9740 - sensitivity_m: 0.9660 - specificity_m: 0.9812 - val_loss: 0.0956 - val_accuracy: 0.9680 - val_sensitivity_m: 0.9534 - val_specificity_m: 0.9793
#
# Epoch 00045: val_loss did not improve from 0.09332
# Epoch 46/50
# 83/83 [==============================] - 46s 554ms/step - loss: 0.0722 - accuracy: 0.9710 - sensitivity_m: 0.9610 - specificity_m: 0.9785 - val_loss: 0.0959 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9509 - val_specificity_m: 0.9793
#
# Epoch 00046: val_loss did not improve from 0.09332
# Epoch 47/50
# 83/83 [==============================] - 47s 562ms/step - loss: 0.0706 - accuracy: 0.9735 - sensitivity_m: 0.9659 - specificity_m: 0.9802 - val_loss: 0.0956 - val_accuracy: 0.9676 - val_sensitivity_m: 0.9519 - val_specificity_m: 0.9793
#
# Epoch 00047: val_loss did not improve from 0.09332
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 1.2800001059076749e-08.
# Epoch 48/50
# 83/83 [==============================] - 47s 561ms/step - loss: 0.0684 - accuracy: 0.9726 - sensitivity_m: 0.9593 - specificity_m: 0.9830 - val_loss: 0.0958 - val_accuracy: 0.9676 - val_sensitivity_m: 0.9519 - val_specificity_m: 0.9793
#
# Epoch 00048: val_loss did not improve from 0.09332
# Epoch 49/50
# 83/83 [==============================] - 46s 554ms/step - loss: 0.0690 - accuracy: 0.9734 - sensitivity_m: 0.9656 - specificity_m: 0.9799 - val_loss: 0.0959 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9509 - val_specificity_m: 0.9793
#
# Epoch 00049: val_loss did not improve from 0.09332
# Epoch 50/50
# 83/83 [==============================] - 47s 560ms/step - loss: 0.0767 - accuracy: 0.9697 - sensitivity_m: 0.9618 - specificity_m: 0.9769 - val_loss: 0.0959 - val_accuracy: 0.9672 - val_sensitivity_m: 0.9509 - val_specificity_m: 0.9793
#
# Epoch 00050: val_loss did not improve from 0.09332

# %%
history_df = pd.DataFrame(history.history)
history_df[['loss', 'val_loss']].plot()
history_df[['accuracy', 'val_accuracy']].plot()

# %%
x_test, y_test = data_generator(path='../input/diabetic-retinopathy/test')

y_test = np_utils.to_categorical(y_test, 5)

y_test_multi = np.empty(y_test.shape, dtype=y_test.dtype)
y_test_multi[:, 4] = y_test[:, 4]

for i in range(3, -1, -1):
    y_test_multi[:, i] = np.logical_or(y_test[:, i], y_test_multi[:, i+1])
# Out:
# 100%|██████████| 500/500 [01:15<00:00,  6.61it/s]

# %%
score = model.evaluate(x_test, y_test_multi)
y_pred = model.predict(x_test)
pred = []
for i in y_pred:
    temp = []
    for j in i:
        rd = round(j)
        temp.append(rd)
    pred.append(temp)
pred = np.array(pred)
print('Test Accuracy:', score[1]*100)
print('Sensitivity:',np.array(sensitivity_m(y_test_multi, pred)))
print('Specificity:',np.array(specificity_m(y_test_multi, pred)))
# Out:
# 500/500 [==============================] - 2s 5ms/step
# Test Accuracy: 96.40000462532043
# Sensitivity: 0.943662
# Specificity: 0.9790941

# %%
from mlxtend.evaluate import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sn

true = []
temp = pred
pred = []
classes = ['No DR', 'Mild', 'Moderate', 'Severe', 'Proliferative DR']
for i in y_test_multi:
    true.append(sum(i))
true = np.array(true)
for i in temp:
    pred.append(sum(i))
pred = np.array(pred)
cm = confusion_matrix(y_target=true,y_predicted=pred,binary=False)
df_cm = pd.DataFrame(cm, index = [i for i in classes],
                  columns = [i for i in classes])
plt.figure(figsize = (10,7))
sn.heatmap(df_cm, annot=True,fmt='g')
